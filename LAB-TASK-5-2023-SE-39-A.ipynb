# %%
from PIL import Image
import matplotlib.pyplot as plt

# Path to the image file
image_path = '/content/Screenshot 2025-12-17 140541' # You can change this to '/content/image5(a).png' or another image

try:
    # Open the image
    img = Image.open(image_path)

    # Display the image
    plt.imshow(img)
    plt.axis('off') # Hide axes
    plt.show()
except FileNotFoundError:
    print(f"Error: The file at {image_path} was not found. Please check the path.")
except Exception as e:
    print(f"An error occurred: {e}")

# %%
from PIL import Image, ImageFilter
import matplotlib.pyplot as plt

# Assuming 'img' is already loaded from the previous cell.
# If not, you might need to reload it:
# image_path = '/content/img5.jpg'
# try:
#     img = Image.open(image_path)
# except FileNotFoundError:
#     print(f"Error: The file at {image_path} was not found. Please check the path.")
#     exit()

# Check if 'img' variable exists and is an Image object
if 'img' in locals() and isinstance(img, Image.Image):
    # Apply a mean filter (BoxBlur) with a radius of 3
    # The radius parameter in BoxBlur corresponds to (2*radius + 1)x(2*radius + 1) kernel size.
    # So, radius=1 means a 3x3 kernel, radius=2 means a 5x5 kernel, etc.
    filtered_img = img.filter(ImageFilter.BoxBlur(3))

    # Display the original and filtered images side by side
    plt.figure(figsize=(12, 6))

    plt.subplot(1, 2, 1)
    plt.imshow(img)
    plt.title('Original Image')
    plt.axis('off')

    plt.subplot(1, 2, 2)
    plt.imshow(filtered_img)
    plt.title('Mean Filtered Image (Radius 3)')
    plt.axis('off')

    plt.show()
else:
    print("Original image 'img' not found. Please ensure the previous cell was executed successfully.")

# %%
from PIL import Image, ImageFilter
import matplotlib.pyplot as plt

# Check if 'img' variable exists and is an Image object
if 'img' in locals() and isinstance(img, Image.Image):
    # Apply a median filter with a size of 3
    filtered_img_median = img.filter(ImageFilter.MedianFilter(size=3))

    # Display the original and median filtered images side by side
    plt.figure(figsize=(12, 6))

    plt.subplot(1, 2, 1)
    plt.imshow(img)
    plt.title('Original Image')
    plt.axis('off')

    plt.subplot(1, 2, 2)
    plt.imshow(filtered_img_median)
    plt.title('Median Filtered Image (Size 3)')
    plt.axis('off')

    plt.show()
else:
    print("Original image 'img' not found. Please ensure the previous cell that loads the image was executed successfully.")

# %%
from PIL import Image, ImageFilter
import matplotlib.pyplot as plt

# Check if 'img' variable exists and is an Image object
if 'img' in locals() and isinstance(img, Image.Image):
    # Apply a mode filter with a size of 3. This filter finds the most frequent pixel value in a neighborhood.
    filtered_img_mode = img.filter(ImageFilter.ModeFilter(size=3))

    # Display the original and mode filtered images side by side
    plt.figure(figsize=(12, 6))

    plt.subplot(1, 2, 1)
    plt.imshow(img)
    plt.title('Original Image')
    plt.axis('off')

    plt.subplot(1, 2, 2)
    plt.imshow(filtered_img_mode)
    plt.title('Mode Filtered Image (Size 3)')
    plt.axis('off')

    plt.show()
else:
    print("Original image 'img' not found. Please ensure the previous cell that loads the image was executed successfully.")

# %%
from PIL import Image, ImageFilter
import matplotlib.pyplot as plt

# Check if 'img' variable exists and is an Image object
if 'img' in locals() and isinstance(img, Image.Image):
    # Apply a Gaussian blur filter with a radius of 2
    filtered_img_gaussian = img.filter(ImageFilter.GaussianBlur(radius=2))

    # Display the original and Gaussian filtered images side by side
    plt.figure(figsize=(12, 6))

    plt.subplot(1, 2, 1)
    plt.imshow(img)
    plt.title('Original Image')
    plt.axis('off')

    plt.subplot(1, 2, 2)
    plt.imshow(filtered_img_gaussian)
    plt.title('Gaussian Filtered Image (Radius 2)')
    plt.axis('off')

    plt.show()
else:
    print("Original image 'img' not found. Please ensure the previous cell that loads the image was executed successfully.")

# %%
from PIL import Image, ImageFilter
import matplotlib.pyplot as plt

image_path = '/content/img5.jpg'

try:
    # Open the original image
    img = Image.open(image_path)

    # Apply filters
    filtered_img_mean = img.filter(ImageFilter.BoxBlur(3))
    filtered_img_median = img.filter(ImageFilter.MedianFilter(size=3))
    filtered_img_mode = img.filter(ImageFilter.ModeFilter(size=3))
    filtered_img_gaussian = img.filter(ImageFilter.GaussianBlur(radius=2))

    # Create a figure with multiple subplots
    plt.figure(figsize=(18, 12))

    # Original Image
    plt.subplot(2, 3, 1) # 2 rows, 3 columns, 1st plot
    plt.imshow(img)
    plt.title('Original Image')
    plt.axis('off')

    # Mean Filtered Image
    plt.subplot(2, 3, 2) # 2 rows, 3 columns, 2nd plot
    plt.imshow(filtered_img_mean)
    plt.title('Mean Filter (BoxBlur Radius 3)')
    plt.axis('off')

    # Median Filtered Image
    plt.subplot(2, 3, 3) # 2 rows, 3 columns, 3rd plot
    plt.imshow(filtered_img_median)
    plt.title('Median Filter (Size 3)')
    plt.axis('off')

    # Mode Filtered Image
    plt.subplot(2, 3, 4) # 2 rows, 3 columns, 4th plot
    plt.imshow(filtered_img_mode)
    plt.title('Mode Filter (Size 3)')
    plt.axis('off')

    # Gaussian Filtered Image
    plt.subplot(2, 3, 5) # 2 rows, 3 columns, 5th plot
    plt.imshow(filtered_img_gaussian)
    plt.title('Gaussian Filter (Radius 2)')
    plt.axis('off')

    plt.tight_layout() # Adjust subplot parameters for a tight layout
    plt.show()

except FileNotFoundError:
    print(f"Error: The file at {image_path} was not found. Please check the path.")
except Exception as e:
    print(f"An error occurred: {e}")

# %% [markdown]
# # Task
# Apply mean, median, mode, and Gaussian filters to the image located at `/content/img5.jpg` and display the original along with all filtered versions for comparison.

# %% [markdown]
# ## apply_multiple_filters
#
# ### Subtask:
# Apply mean, median, mode, and Gaussian filters to the image and display the original along with all filtered versions for comparison.

# %% [markdown]
# ## Summary:
#
# ### Data Analysis Key Findings
# *   **Original Image Displayed:** The initial image from `/content/img5.jpg` was successfully loaded and displayed as a baseline for comparison.
# *   **Mean Filter Application:** A mean filter was applied, resulting in a smoothed version of the image. This filter typically blurs edges and reduces noise by averaging pixel values within a neighborhood.
# *   **Median Filter Application:** The median filter was used, which is effective at removing salt-and-pepper noise while generally preserving edges better than the mean filter.
# *   **Mode Filter Application:** A mode filter was applied. This filter replaces each pixel's value with the most frequent value in its neighborhood, which can be useful for certain types of noise reduction or segmentation.
# *   **Gaussian Filter Application:** The Gaussian filter produced a smoothly blurred image. This filter uses a Gaussian function to calculate the transformation to apply to each pixel, providing a more natural-looking blur and effective noise reduction, especially for Gaussian noise.
# *   **Comparative Display:** All filtered images were displayed alongside the original, allowing for a direct visual comparison of the distinct effects of each filtering technique on the image's characteristics, such as detail, sharpness, and noise reduction.
#
# ### Insights or Next Steps
# *   The choice of filter significantly impacts the image's visual quality, with different filters excelling at reducing specific types of noise or achieving different aesthetic effects (e.g., median for salt-and-pepper noise, Gaussian for general smoothing).
# *   Further analysis could involve quantitatively evaluating the effectiveness of each filter, perhaps by introducing known noise to an image and measuring the signal-to-noise ratio or structural similarity index (SSIM) after filtering, to determine optimal filter parameters for specific use cases.
