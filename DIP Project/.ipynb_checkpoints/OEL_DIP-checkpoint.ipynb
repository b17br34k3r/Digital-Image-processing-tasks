# %% [markdown]
# # STEP 0: Environment Setup & Library Imports
#
# Initialize Python environment by importing all required libraries for image processing, data handling, and machine learning.

# %%
# ✅ Import libraries
import os
import cv2
import numpy as np
import pandas as pd
from tqdm import tqdm
import matplotlib.pyplot as plt

from sklearn.metrics import confusion_matrix, classification_report, accuracy_score, f1_score
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier

print("Libraries imported successfully!")
# Out:
# Libraries imported successfully!

# %% [markdown]
# # STEP 1: Define Dataset Paths
#
# Configure file paths for accessing the PH2 dataset and setting up output directories for saving generated segmentation masks.

# %%
BASE_PATH = r"C:\Users\hp\DIP Project\PH2Dataset\PH2 Dataset images"
MASK_SAVE_PATH = "C:/users/hp/DIP Project/PH2Dataset/generated_masks"
LABEL_TXT = "C:/users/hp/DIP Project/PH2Dataset/PH2_dataset.txt"

os.makedirs(MASK_SAVE_PATH, exist_ok=True)

# %% [markdown]
# # STEP 2: Image Pre-Processing Functions
#
# Define preprocessing functions to enhance image quality and prepare images for accurate lesion segmentation using contrast enhancement (CLAHE) and hair removal.

# %%
def enhance_image(img):
    lab = cv2.cvtColor(img, cv2.COLOR_BGR2LAB)
    l, a, b = cv2.split(lab)
    clahe = cv2.createCLAHE(clipLimit=2.0, tileGridSize=(8,8))
    l = clahe.apply(l)
    lab = cv2.merge([l, a, b])
    return cv2.cvtColor(lab, cv2.COLOR_LAB2BGR)

# %% [markdown]
# # STEP 2.2: Hair Removal Function
#
# Detect and remove hair artifacts using morphological operations and image inpainting.

# %%
def remove_hairs(img):
    gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    kernel = cv2.getStructuringElement(cv2.MORPH_RECT, (17,17))
    blackhat = cv2.morphologyEx(gray, cv2.MORPH_BLACKHAT, kernel)
    _, mask = cv2.threshold(blackhat, 10, 255, cv2.THRESH_BINARY)
    return cv2.inpaint(img, mask, 1, cv2.INPAINT_TELEA)

# %% [markdown]
# # STEP 3: Lesion Segmentation
#
# Isolate the melanoma lesion from surrounding skin tissue using binary thresholding and morphological operations.

# %%
def segment_lesion(img):
    gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    blur = cv2.GaussianBlur(gray, (5,5), 0)
    _, binary = cv2.threshold(blur, 0, 255, cv2.THRESH_BINARY_INV + cv2.THRESH_OTSU)
    kernel = np.ones((5,5), np.uint8)
    binary = cv2.morphologyEx(binary, cv2.MORPH_CLOSE, kernel)
    binary = cv2.morphologyEx(binary, cv2.MORPH_OPEN, kernel)
    binary = cv2.morphologyEx(binary, cv2.MORPH_ERODE, kernel, iterations=1)
    return binary

# %% [markdown]
# # STEP 4: Generate Masks & Segmentation Evaluation
#
# Process entire dataset to generate segmentation masks, save them to disk, and calculate segmentation performance metrics.

# %%
y_true_all, y_pred_all = [], []
sample_count = 0

for folder in tqdm(os.listdir(BASE_PATH)):
    folder_path = os.path.join(BASE_PATH, folder)
    if not os.path.isdir(folder_path):
        continue
    img_path = os.path.join(folder_path, f"{folder}_Dermoscopic_Image")
    gt_path  = os.path.join(folder_path, f"{folder}_lesion")
    if not os.path.exists(img_path) or not os.path.exists(gt_path):
        continue
    img = cv2.imread(os.path.join(img_path, os.listdir(img_path)[0]))
    gt  = cv2.imread(os.path.join(gt_path, os.listdir(gt_path)[0]), 0)
    if img is None or gt is None:
        continue
    img_enhanced = enhance_image(img)
    img_preprocessed = remove_hairs(img_enhanced)
    pred_mask = segment_lesion(img_preprocessed)
    cv2.imwrite(os.path.join(MASK_SAVE_PATH, f"{folder}_mask.png"), pred_mask)
    y_true_all.extend((gt > 0).flatten())
    y_pred_all.extend((pred_mask > 0).flatten())
    
    # Display sample images
    sample_count += 1
    if sample_count <= 3:  # Show first 3 samples
        fig, axes = plt.subplots(1, 4, figsize=(16, 4))
        axes[0].imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))
        axes[0].set_title("Original Image")
        axes[0].axis('off')
        axes[1].imshow(cv2.cvtColor(img_preprocessed, cv2.COLOR_BGR2RGB))
        axes[1].set_title("Preprocessed (Enhanced + Hair Removed)")
        axes[1].axis('off')
        axes[2].imshow(pred_mask, cmap='gray')
        axes[2].set_title("Generated Segmentation Mask")
        axes[2].axis('off')
        axes[3].imshow(cv2.cvtColor(gt, cv2.COLOR_GRAY2RGB))
        axes[3].set_title("Ground Truth Mask")
        axes[3].axis('off')
        plt.tight_layout()
        plt.show()
# Out:
# ...
# 100%|██████████| 200/200 [03:39<00:00,  1.10s/it]

# %% [markdown]
# # STEP 4.2: Segmentation Performance Metrics
#
# Analyze and display segmentation accuracy by computing metrics from the confusion matrix.

# %%
cm = confusion_matrix(y_true_all, y_pred_all)
TN, FP, FN, TP = cm.ravel()

accuracy = (TP + TN) / (TP + TN + FP + FN)
sensitivity = TP / (TP + FN)
specificity = TN / (TN + FP)

print("Confusion Matrix:\n", cm)
print(f"Accuracy     : {accuracy:.4f}")
print(f"Sensitivity  : {sensitivity:.4f}")
print(f"Specificity  : {specificity:.4f}")
# Out:
# Confusion Matrix:
#  [[51276698  8450984]
#  [13095584 15340057]]
# Accuracy     : 0.7556
# Sensitivity  : 0.5395
# Specificity  : 0.8585

# %% [markdown]
# # STEP 5: Load Clinical Labels from .txt File
#
# Parse the PH2 dataset label file to extract clinical diagnoses and create a dictionary mapping image IDs to binary class labels (Melanoma vs Non-Melanoma).

# %%
label_dict = {}

with open(LABEL_TXT, "r") as f:
    for line in f:
        if line.strip() == "" or line.startswith("Name") or line.startswith("Legends"):
            continue
        parts = [p.strip() for p in line.split("||") if p.strip()]
        if len(parts) < 2:
            continue
        img_id = parts[0]
        clinical_diagnosis = parts[1]
        if "Melanoma" in clinical_diagnosis:
            label_dict[img_id] = 1
        else:
            label_dict[img_id] = 0

print("Total labels loaded:", len(label_dict))
# Out:
# Total labels loaded: 201

# %%
# Verify data availability
print(f"Images found: {len(os.listdir(BASE_PATH))}")
print(f"Labels loaded: {len(label_dict)}")
print(f"Masks directory exists: {os.path.exists(MASK_SAVE_PATH)}")
# Out:
# Images found: 200
# Labels loaded: 201
# Masks directory exists: True

# %% [markdown]
# # STEP 6: Feature Extraction from Segmented Lesion Region
#
# Extract meaningful features from the masked lesion area for use in machine learning classification.

# %%
def extract_features(img, mask):
    _, mask_bin = cv2.threshold(mask, 127, 255, cv2.THRESH_BINARY)
    features = []
    for i in range(3):
        pixels = img[:,:,i][mask_bin > 0]
        if pixels.size == 0:
            features.extend([0, 0])
        else:
            features.extend([pixels.mean(), pixels.std()])
    return features

# %% [markdown]
# # STEP 7: Build Dataset (Feature Matrix X and Label Vector y)
#
# Assemble the complete machine learning dataset by processing all labeled images, extracting features, and creating the feature matrix and label vector.

# %%
X, y = [], []
sample_images_displayed = 0

for folder in os.listdir(BASE_PATH):
    if folder not in label_dict:
        continue
    mask_path = os.path.join(MASK_SAVE_PATH, f"{folder}_mask.png")
    img_folder = os.path.join(BASE_PATH, folder, f"{folder}_Dermoscopic_Image")
    if not os.path.exists(mask_path) or not os.path.exists(img_folder):
        continue
    img = cv2.imread(os.path.join(img_folder, os.listdir(img_folder)[0]))
    mask = cv2.imread(mask_path, 0)
    if img is None or mask is None:
        continue
    features = extract_features(img, mask)
    X.append(features)
    label = label_dict[folder]
    y.append(label)
    
    # Display sample images with extracted features
    sample_images_displayed += 1
    if sample_images_displayed <= 4:  # Show first 4 samples
        fig, axes = plt.subplots(1, 2, figsize=(10, 4))
        axes[0].imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))
        axes[0].set_title(f"Image {folder}")
        axes[0].axis('off')
        axes[1].imshow(mask, cmap='gray')
        axes[1].set_title(f"Mask - Label: {'Melanoma' if label == 1 else 'Benign'}\nFeatures: {[f'{f:.1f}' for f in features[:2]]}")
        axes[1].axis('off')
        plt.tight_layout()
        plt.show()

X = np.array(X)
y = np.array(y)

print("Feature matrix:", X.shape)
print("Labels:", y.shape)
print(f"\nDataset Summary:")
print(f"Total samples: {len(y)}")
print(f"Melanoma: {np.sum(y)} | Benign: {np.sum(y == 0)}")
# Out:
# Feature matrix: (200, 6)
# Labels: (200,)
#
# Dataset Summary:
# Total samples: 200
# Melanoma: 28 | Benign: 172

# %% [markdown]
# # STEP 8: Train/Test Split
#
# Divide the dataset into training (75%) and testing (25%) subsets with stratified class distribution for proper model evaluation.

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.25, random_state=42, stratify=y
)

print(f"X_train: {X_train.shape}, X_test: {X_test.shape}")
print(f"y_train: {y_train.shape}, y_test: {y_test.shape}")
# Out:
# X_train: (150, 6), X_test: (50, 6)
# y_train: (150,), y_test: (50,)

# %%
clf = RandomForestClassifier(n_estimators=80, max_depth=8, random_state=42)
clf.fit(X_train, y_train)

y_pred = clf.predict(X_test)
print(f"Model trained. Predictions shape: {y_pred.shape}")
# Out:
# Model trained. Predictions shape: (50,)

# %% [markdown]
# # STEP 9: Classifier Performance Evaluation
#
# Evaluate the trained Random Forest classifier using standard machine learning metrics to assess performance.

# %%
acc = accuracy_score(y_test, y_pred)
f1 = f1_score(y_test, y_pred)

print(f"Accuracy: {acc:.4f}")
print(f"F1 Score: {f1:.4f}")
print("\nClassification Report:")
print(classification_report(y_test, y_pred))

# Display confusion matrix visualization
from sklearn.metrics import confusion_matrix as cm_func
cm = cm_func(y_test, y_pred)
plt.figure(figsize=(8, 6))
plt.imshow(cm, interpolation='nearest', cmap=plt.cm.Blues)
plt.title('Confusion Matrix')
plt.colorbar()
plt.ylabel('True Label')
plt.xlabel('Predicted Label')
tick_marks = np.arange(2)
plt.xticks(tick_marks, ['Benign', 'Melanoma'])
plt.yticks(tick_marks, ['Benign', 'Melanoma'])

# Add text annotations
for i in range(cm.shape[0]):
    for j in range(cm.shape[1]):
        plt.text(j, i, str(cm[i, j]), ha='center', va='center', color='white' if cm[i, j] > cm.max() / 2 else 'black')

plt.tight_layout()
plt.show()

# Feature importance visualization
feature_names = ['B_mean', 'B_std', 'G_mean', 'G_std', 'R_mean', 'R_std']
importances = clf.feature_importances_
plt.figure(figsize=(10, 6))
plt.barh(feature_names, importances)
plt.xlabel('Importance')
plt.title('Feature Importance - Random Forest Classifier')
plt.tight_layout()
plt.show()
# Out:
# Accuracy: 0.8800
# F1 Score: 0.4000
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.89      0.98      0.93        43
#            1       0.67      0.29      0.40         7
#
#     accuracy                           0.88        50
#    macro avg       0.78      0.63      0.67        50
# weighted avg       0.86      0.88      0.86        50

# %%
# Learning curve (training & validation accuracy)
from sklearn.model_selection import learning_curve, ShuffleSplit
from sklearn.metrics import log_loss
from sklearn.base import clone
import numpy as np
import matplotlib.pyplot as plt
from sklearn.ensemble import RandomForestClassifier

# Create a fresh estimator with same hyperparameters
est = RandomForestClassifier(n_estimators=80, max_depth=8, random_state=42)

# Compute learning curve (accuracy)
train_sizes, train_scores, val_scores = learning_curve(
    est, X, y, cv=5, train_sizes=np.linspace(0.1, 1.0, 5), scoring='accuracy', n_jobs=-1
)
train_mean = np.mean(train_scores, axis=1)
val_mean = np.mean(val_scores, axis=1)

plt.figure(figsize=(8, 6))
plt.plot(train_sizes, train_mean, 'o-', label='Training Accuracy')
plt.plot(train_sizes, val_mean, 'o-', label='Validation Accuracy')
plt.xlabel('Training examples')
plt.ylabel('Accuracy')
plt.title('Learning Curve - Accuracy')
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# Training & validation loss (log loss) vs training size
train_losses = []
val_losses = []
cv = ShuffleSplit(n_splits=5, test_size=0.25, random_state=42)
train_sizes_abs = np.array(train_sizes, dtype=int)

for n in train_sizes_abs:
    fold_tr_losses = []
    fold_val_losses = []
    for train_idx, val_idx in cv.split(X):
        # select a subset of the training indices (if needed)
        if n < len(train_idx):
            sub_idx = np.random.choice(train_idx, n, replace=False)
        else:
            sub_idx = train_idx
        clf_sub = clone(est)
        clf_sub.fit(X[sub_idx], y[sub_idx])
        proba_tr = clf_sub.predict_proba(X[sub_idx])
        proba_val = clf_sub.predict_proba(X[val_idx])
        # log_loss expects probabilities for all classes
        fold_tr_losses.append(log_loss(y[sub_idx], proba_tr, labels=[0,1]))
        fold_val_losses.append(log_loss(y[val_idx], proba_val, labels=[0,1]))
    train_losses.append(np.mean(fold_tr_losses))
    val_losses.append(np.mean(fold_val_losses))

plt.figure(figsize=(8, 6))
plt.plot(train_sizes_abs, train_losses, 'o-', label='Training Log Loss')
plt.plot(train_sizes_abs, val_losses, 'o-', label='Validation Log Loss')
plt.xlabel('Training examples')
plt.ylabel('Log Loss')
plt.title('Learning Curve - Log Loss')
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# Comparison bar chart: true vs predicted counts on test set
counts_true = np.bincount(y_test) if len(y_test) > 0 else np.array([0,0])
counts_pred = np.bincount(y_pred) if len(y_pred) > 0 else np.array([0,0])
# Ensure both arrays have length 2 (Benign, Melanoma)
counts_true = np.pad(counts_true, (0, max(0, 2 - counts_true.size)), 'constant')
counts_pred = np.pad(counts_pred, (0, max(0, 2 - counts_pred.size)), 'constant')
labels = ['Benign', 'Melanoma']
x = np.arange(len(labels))
width = 0.35
plt.figure(figsize=(6, 4))
plt.bar(x - width/2, counts_true, width, label='True')
plt.bar(x + width/2, counts_pred, width, label='Predicted')
plt.xticks(x, labels)
plt.ylabel('Counts')
plt.title('True vs Predicted Label Distribution (Test Set)')
plt.legend()
plt.tight_layout()
plt.show()

print('Learning-curve and comparison plots generated.')
# Out:
# Learning-curve and comparison plots generated.
